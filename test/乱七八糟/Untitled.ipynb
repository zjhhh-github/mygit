# %%
import pandas as pd

# %%
c = 0
l = []
for i in range(1,7000):
    c += 1
    if c < 200:
        if c == 1:
            ss = str(i)
            ss.rjust(6, "0")
            s = ss
            print(ss)
        elif c == 199:
            ss = str(i)
            ss.rjust(6, "0")
            s = s + '-' + ss
            # print(s)
            c = 0
            l.append(s)
print(l)
# Out:
# 1
# 200
# 399
# 598
# 797
# 996
# 1195
# 1394
# 1593
# 1792
# 1991
# 2190
# 2389
# 2588
# 2787
# 2986
# 3185
# 3384
# 3583
# 3782
# 3981
# 4180
# 4379
# 4578
# 4777
# 4976
# 5175
# 5374
# 5573
# 5772
# 5971
# 6170
# 6369
# 6568
# 6767
# 6966
# ['1-199', '200-398', '399-597', '598-796', '797-995', '996-1194', '1195-1393', '1394-1592', '1593-1791', '1792-1990', '1991-2189', '2190-2388', '2389-2587', '2588-2786', '2787-2985', '2986-3184', '3185-3383', '3384-3582', '3583-3781', '3782-3980', '3981-4179', '4180-4378', '4379-4577', '4578-4776', '4777-4975', '4976-5174', '5175-5373', '5374-5572', '5573-5771', '5772-5970', '5971-6169', '6170-6368', '6369-6567', '6568-6766', '6767-6965']

# %%
'1'.rjust(6, "0")
# Out:
# '000001'
